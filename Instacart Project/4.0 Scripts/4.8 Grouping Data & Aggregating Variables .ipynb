# %% [markdown]
# # 4.8 Grouping Data & Aggregating Variables

# %% [markdown]
# ## This script contains the following:
# 1. Importing libraries and data
# 2. Find aggregated mean of order_number column grouped by department_id
# 3.Creating loyalty flags for existing customers using the transform () and loc()
# 4. Creating a spending flag for each user based on average price
# 5. Creating an order frequency flag.

# %% [markdown]
# ### Importing libraries and data

# %%
#Import libraries 
import pandas as pd
import numpy as np
import os

# %%
#Set Path 
path= r'C:\Users\hmaio\Documents\4.0 Instacart Project'

# %%
# Import Data 
df_ords_prods_merged = pd.read_pickle(os.path.join(path, '4.0 Data', 'Prepared Data', 'orders_products_adjusted.pkl'))

# %% [markdown]
# ### Find aggregated mean of order_number grouped by department_id

# %%
# spliting data into groups based on department_id and apply agg() function to each group to obtain mean values 
df_ords_prods_merged.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                16.559358
# 2                18.413176
# 3                18.279600
# 4                18.915890
# 5                16.497751
# 6                17.609390
# 7                18.303975
# 8                16.383301
# 9                17.022963
# 10               21.227447
# 11               17.311768
# 12               16.953613
# 13               17.727470
# 14               17.898097
# 15               17.290123
# 16               18.757796
# 17               16.808683
# 18               20.336389
# 19               18.258620
# 20               17.578959
# 21               23.644477

# %% [markdown]
# Comparing this output to the ones from the subset there a few differences. Department 4 average is still 19 however it is no longer the most. That belongs to department 21. Department 11 average is closer to other departments now. FInally department 8 has the lowest average of 16.3.

# %% [markdown]
# ### Creating loyalty flags for existing customers

# %%
#creating max order column 
df_ords_prods_merged['max_order'] =df_ords_prods_merged.groupby(['user_id'])['order_number'].transform(np.max)

# %%
#checking output 
df_ords_prods_merged.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_time_of_day  \
# 0    2398795        1             2                   3                  7
# 1     473747        1             3                   3                 12
# 2    2254736        1             4                   4                  7
# 3     431534        1             5                   4                 15
# 4    3367565        1             6                   2                  7
# 5     550135        1             7                   1                  9
# 6    3108588        1             8                   1                 14
# 7    2295261        1             9                   1                 16
# 8    2550362        1            10                   4                  8
# 9    2968173       15            15                   1                  9
# 10   1870022       15            17                   2                 16
# 11   1911383       15            18                   2                 11
# 12   2715276       15            21                   1                  9
# 13    487368       15            22                   1                 10
# 14   2293453       19             2                   5                 14
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     15.0         196                  1          1
# 1                     21.0         196                  1          1
# 2                     29.0         196                  1          1
# 3                     28.0         196                  1          1
# 4                     19.0         196                  1          1
# 5                     20.0         196                  1          1
# 6                     14.0         196                  2          1
# 7                      0.0         196                  4          1
# 8                     30.0         196                  1          1
# 9                      7.0         196                  2          0
# 10                     8.0         196                  6          1
# 11                     7.0         196                  1          1
# 12                     7.0         196                  1          1
# 13                    14.0         196                  1          1
# 14                     6.0         196                  3          0
#
#    product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# 0          Soda        77              7     9.0   both  Mid-Range Product
# 1          Soda        77              7     9.0   both  Mid-Range Product
# 2          Soda        77              7     9.0   both  Mid-Range Product
# 3          Soda        77              7     9.0   both  Mid-Range Product
# 4          Soda        77              7     9.0   both  Mid-Range Product
# 5          Soda        77              7     9.0   both  Mid-Range Product
# 6          Soda        77              7     9.0   both  Mid-Range Product
# 7          Soda        77              7     9.0   both  Mid-Range Product
# 8          Soda        77              7     9.0   both  Mid-Range Product
# 9          Soda        77              7     9.0   both  Mid-Range Product
# 10         Soda        77              7     9.0   both  Mid-Range Product
# 11         Soda        77              7     9.0   both  Mid-Range Product
# 12         Soda        77              7     9.0   both  Mid-Range Product
# 13         Soda        77              7     9.0   both  Mid-Range Product
# 14         Soda        77              7     9.0   both  Mid-Range Product
#
#           busiest_days busiest_period_of_day  max_order
# 0   Least busiest days        Average orders         10
# 1   Least busiest days           Most orders         10
# 2   Least busiest days        Average orders         10
# 3   Least busiest days           Most orders         10
# 4       Regularly busy        Average orders         10
# 5         Busiest days        Average orders         10
# 6         Busiest days           Most orders         10
# 7         Busiest days           Most orders         10
# 8   Least busiest days        Average orders         10
# 9         Busiest days        Average orders         22
# 10      Regularly busy           Most orders         22
# 11      Regularly busy           Most orders         22
# 12        Busiest days        Average orders         22
# 13        Busiest days           Most orders         22
# 14      Regularly busy           Most orders          9

# %%
#creating loyal flag 
df_ords_prods_merged.loc[df_ords_prods_merged['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
df_ords_prods_merged.loc[(df_ords_prods_merged['max_order'] <= 40) & (df_ords_prods_merged['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
df_ords_prods_merged.loc[df_ords_prods_merged['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# frequency check 
df_ords_prods_merged['loyalty_flag'].value_counts (dropna= False)
# Out:
# Regular customer    15081691
# Loyal customer      10095381
# New customer         5151691
# Name: loyalty_flag, dtype: int64

# %%
#check the basic statistics of the product prices for each loyal customer  
df_ords_prods_merged.groupby('loyalty_flag').agg({'prices':['mean','max','min']})
# Out:
#                      prices
#                        mean      max  min
# loyalty_flag
# Loyal customer    10.402162  99999.0  1.0
# New customer      13.396333  99999.0  1.0
# Regular customer  12.546842  99999.0  1.0

# %% [markdown]
# New customers are spending the most while loyal customers spend the least

# %% [markdown]
# ###  Creating a spending flag

# %%
#creating average spent column 
df_ords_prods_merged['avg_spent'] =df_ords_prods_merged.groupby(['user_id'])['prices'].transform(np.mean)

# %%
#check output 
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time_of_day  \
# 0   2398795        1             2                   3                  7
# 1    473747        1             3                   3                 12
# 2   2254736        1             4                   4                  7
# 3    431534        1             5                   4                 15
# 4   3367565        1             6                   2                  7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                    15.0         196                  1          1
# 1                    21.0         196                  1          1
# 2                    29.0         196                  1          1
# 3                    28.0         196                  1          1
# 4                    19.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# 0         Soda        77              7     9.0   both  Mid-Range Product
# 1         Soda        77              7     9.0   both  Mid-Range Product
# 2         Soda        77              7     9.0   both  Mid-Range Product
# 3         Soda        77              7     9.0   both  Mid-Range Product
# 4         Soda        77              7     9.0   both  Mid-Range Product
#
#          busiest_days busiest_period_of_day  max_order  loyalty_flag  \
# 0  Least busiest days        Average orders         10  New customer
# 1  Least busiest days           Most orders         10  New customer
# 2  Least busiest days        Average orders         10  New customer
# 3  Least busiest days           Most orders         10  New customer
# 4      Regularly busy        Average orders         10  New customer
#
#    avg_spent
# 0   6.372222
# 1   6.372222
# 2   6.372222
# 3   6.372222
# 4   6.372222

# %%
# creating spending flag 
df_ords_prods_merged.loc[df_ords_prods_merged['avg_spent'] >= 10, 'spender_flag'] = 'High spender'
df_ords_prods_merged.loc[df_ords_prods_merged['avg_spent'] < 10, 'spender_flag'] = 'Low spender'

# %%
# check frequency 
df_ords_prods_merged['spender_flag'].value_counts (dropna= False)
# Out:
# Low spender     29730505
# High spender      598258
# Name: spender_flag, dtype: int64

# %% [markdown]
# ###  Order Frequency Flag

# %%
# creating median days since order column
df_ords_prods_merged['median_days_since_order'] =df_ords_prods_merged.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
#check output 
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time_of_day  \
# 0   2398795        1             2                   3                  7
# 1    473747        1             3                   3                 12
# 2   2254736        1             4                   4                  7
# 3    431534        1             5                   4                 15
# 4   3367565        1             6                   2                  7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                    15.0         196                  1          1
# 1                    21.0         196                  1          1
# 2                    29.0         196                  1          1
# 3                    28.0         196                  1          1
# 4                    19.0         196                  1          1
#
#   product_name  ...  prices  _merge    price_range_loc        busiest_days  \
# 0         Soda  ...     9.0    both  Mid-Range Product  Least busiest days
# 1         Soda  ...     9.0    both  Mid-Range Product  Least busiest days
# 2         Soda  ...     9.0    both  Mid-Range Product  Least busiest days
# 3         Soda  ...     9.0    both  Mid-Range Product  Least busiest days
# 4         Soda  ...     9.0    both  Mid-Range Product      Regularly busy
#
#   busiest_period_of_day max_order  loyalty_flag  avg_spent spender_flag  \
# 0        Average orders        10  New customer   6.372222  Low spender
# 1           Most orders        10  New customer   6.372222  Low spender
# 2        Average orders        10  New customer   6.372222  Low spender
# 3           Most orders        10  New customer   6.372222  Low spender
# 4        Average orders        10  New customer   6.372222  Low spender
#
#    median_days_since_order
# 0                     20.5
# 1                     20.5
# 2                     20.5
# 3                     20.5
# 4                     20.5
#
# [5 rows x 22 columns]

# %%
#creating frequency flag 
df_ords_prods_merged.loc[df_ords_prods_merged['median_days_since_order'] > 20, 'frequency_flag'] = 'Non-frequent customer'
df_ords_prods_merged.loc[(df_ords_prods_merged['median_days_since_order'] > 10) & (df_ords_prods_merged['median_days_since_order'] <= 20), 'frequency_flag'] = 'Regular customer'
df_ords_prods_merged.loc[df_ords_prods_merged['median_days_since_order'] < 10, 'frequency_flag'] = 'Frequent customer'

# %%
#check frequency 
df_ords_prods_merged['frequency_flag'].value_counts (dropna = False)
# Out:
# Frequent customer        19483250
# Regular customer          6594542
# Non-frequent customer     3058931
# NaN                       1192040
# Name: frequency_flag, dtype: int64

# %%
# Exporting data 
df_ords_prods_merged.to_pickle(os.path.join(path, '4.0 Data','Prepared Data', 'orders_products_updated.pkl'))

# %% [markdown]
# ### To replace outliners with missing value

# %%
# this code (not run) would change all the prices above 100 in the price column to nan. 
ords_prods_merge.loc[ords_prods_merge['prices'] >100, 'prices'] = np.nan
